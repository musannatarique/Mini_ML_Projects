# %%
import numpy as np
import pandas as pd
import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Data Collection and Analysis**

# %%
#Loading the diabetes dataset to a pandas DataFrame
diabetes_dataset = pd.read_csv(r"D:\000\Code\Py\ML\Data Sheets\Diabetes.csv")

# %%
diabetes_dataset.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
#Number of rows and Columns in this dataset
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
#Getting the statistical measures of the data
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 --> Non-Diabetic
#
# 1 --> Diabetic

# %%
#Separating the data and labels
X = diabetes_dataset.drop(columns = 'Outcome', axis=1)
Y = diabetes_dataset['Outcome']

# %% [markdown]
# **Data Standardization**

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = standardized_data
Y = diabetes_dataset['Outcome']

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# **Training the Model**

# %%
# Creating an SVM classifier with a linear kernel
classifier = svm.SVC(kernel='linear')

# Explanation:
# - 'svm.SVC' initializes a Support Vector Classifier (SVC).
# - 'kernel="linear"' specifies that the classifier should use a linear kernel.
# - A linear kernel is useful when the data is linearly separable, meaning that a straight line (or hyperplane in higher dimensions) can separate different classes.
# - The classifier will try to find the best hyperplane that maximizes the margin between different classes.

# %%
#Training the support vector Machine Classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# **Model Evaluation**

# %%
#Accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7866449511400652

# %%
#Accuracy score on the test data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.7727272727272727

# %% [markdown]
# **Making a Predictive System**

# %%
try:
    print("Please enter the following details:")

    pregnancies = float(input("Number of Pregnancies: "))
    glucose = float(input("Glucose Level: "))
    blood_pressure = float(input("Blood Pressure: "))
    skin_thickness = float(input("Skin Thickness: "))
    insulin = float(input("Insulin Level: "))
    bmi = float(input("BMI: "))
    diabetes_pedigree = float(input("Diabetes Pedigree Function: "))
    age = float(input("Age: "))

    # Create input array
    input_values = (pregnancies, glucose, blood_pressure, skin_thickness, insulin, bmi, diabetes_pedigree, age)
    input_array = np.asarray(input_values).reshape(1, -1)

    # Standardize the input data using the trained scaler
    standardized_data = scaler.transform(input_array)
    print("\nStandardized Input Data:", standardized_data)

    # Predict using the trained classifier
    prediction = classifier.predict(standardized_data)

    # Display result
    if prediction[0] == 0:
        print("\n✅ Prediction: The person is NOT diabetic.")
    else:
        print("\n⚠️ Prediction: The person IS diabetic.")

except ValueError:
    print("\n❗ Invalid input! Please enter numeric values.")
except Exception as error:
    print(f"\n⚠️ An unexpected error occurred: {error}")
# Out:
# Please enter the following details:
#
# Standardized Input Data: [[ 1.81609686e+01 -2.71955077e+00  1.08020025e+00 -9.74571907e-01
#   -2.06648401e-01  9.41978774e-04  6.04397318e-01  1.00055664e+00]]
#
# ⚠️ Prediction: The person IS diabetic.
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
